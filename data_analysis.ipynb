# %%
from sqlalchemy import create_engine
import pandas as pd
from matplotlib import pyplot
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta
import pandas as pd
import numpy as np

# %%
def sensor_summary(this_sensor_df):
    # def sensor_summary(this_sensor_df):
    ### Gathering data for the last month
    this_house_sensor = this_sensor_df.reset_index()

    ### Adding dates so that the function works
    this_house_sensor['date'] = this_house_sensor['timestamp'].dt.date
    last_date = datetime.now() - timedelta(days=30)
    test_var =  this_house_sensor[this_house_sensor['timestamp'] >= last_date.date()]

    if len(test_var['index']) > 0:
        data_last_month  = this_house_sensor[this_house_sensor['timestamp'] >= last_date.date()]

        #Last Day Collected
        last_day = data_last_month['date'][len(data_last_month['date'])-1]

        # Number of Days in Sample
        ndays = len(data_last_month['date'].unique())

        # Number of Samples
        nsamples = len(data_last_month['value'])

        # Count number of NA samples
        count = 0
        for sample in data_last_month['value']:
            if pd.isnull(sample) == True: 
                count += 1

        # Interquartile range
        sum_stats = data_last_month['value'].describe()

        print("Sensor ID is " + str(data_last_month['sensor_id'].unique()[0]))
        print("Sensor Type is " + str(characteris[characteris['sensor_id'] == str(this_house_sensor['sensor_id'].unique()[0])]['type'].reset_index()['type'][0]))
        print("Sensor Type is " + str(data_last_month['sensor_id'].unique()[0]))
        print("Last Date: " + str(last_day))
        print("Number of days in sample: " + str(ndays))
        print("Number of samples: " + str(nsamples))
        print("Number of NAs: " + str(count))
        print(sum_stats)

    else: 
        print("Warning! " + str(this_house_sensor['sensor_id'].unique()[0]) + " doesn't have any data!")
        

    return(data_last_month)

# %%
#Connection to Server to get household luzero data
#Database connection to luzero_server for use in db access
url = 'postgresql://{}:{}@{}:{}/{}'
url = url.format('luzero', 'luzero', 'luzero.niuera.co', 5432, 'luzero_server')
con_total = create_engine(url, client_encoding='utf8')

# %%
# Create engine
# Write this in terminal first:
# ssh -N db.xinampa.io -L 5433:127.0.0.1:5432 &

engine = create_engine('postgresql://diego@localhost:5433/sonora_sensors')

# %%
# Tables in Hermosillo are
#hermosillo_weather (columns:  local_timestamp       |    obs_timestamp    | wind_speed | humidity | temperature | temperature_max | temperature_min |    sunrise_time     |     sunset_time )
# and houses where we've installed sensors
#taqueria

# %%
########## Weather Data
########## 
##########

# %%
df_total = pd.read_sql("select * from hermosillo_weather order by obs_timestamp desc limit 10000",engine)

# %%
df_total_sort = df_total.sort_values(by= 'obs_timestamp', ascending= False)
df_total_sort['date'] = df_total_sort['obs_timestamp'].dt.date

# %%
### Gathering data for the last month
last_date = datetime.now() - timedelta(days=30)

weather_last_month  = df_total_sort[df_total_sort['obs_timestamp'] >= last_date.date()]

#Last Day Collected
last_day = weather_last_month['date'][len(weather_last_month['date'])-1]

# Number of Days in Sample
ndays = len(weather_last_month['date'].unique())

# Number of Samples
nsamples = len(weather_last_month['temperature'])

# Count number of NA samples
count = 0
for sample in weather_last_month['temperature']:
    if pd.isnull(sample) == True: 
        count += 1
        
# Interquartile range
sum_stats = weather_last_month['temperature'].describe()

print("Last Date: " + str(last_day))
print("Number of days in sample: " + str(ndays))
print("Number of samples: " + str(nsamples))
print("Number of NAs: " + str(count))
print(sum_stats)
# Out:
# Last Date: 2019-06-05
# Number of days in sample: 31
# Number of samples: 9398
# Number of NAs: 0
# count    9398.000000
# mean       30.532507
# std         6.257696
# min        16.530000
# 25%        25.750000
# 50%        30.690000
# 75%        35.810000
# max        44.340000
# Name: temperature, dtype: float64

# %%
# Last Thirty Days
plt.plot(weather_last_month.groupby('date')['temperature'].mean())
plt.plot(weather_last_month.groupby('date')['temperature_max'].mean())

# %%
plt.plot(df_total_sort['obs_timestamp'],df_total_sort['temperature_max'])
plt.show()

# %%
##### Senor Data Analysis

#Sensor list
house_sensors = {}
house_sensors['id_1']= ("FCFE","C602","F991")
house_sensors['id_10'] = ("FE44","C2D5","FCE4")
house_sensors['id_9'] = ("EF2C","CF17","F33E")
house_sensors['id_20'] = ("0581","C40B","F9D1")
house_sensors['id_3'] = ("FAF4","C41B","FF88")
house_sensors['id_4'] = ("F99E","C44A","F9E0")
house_sensors['id_11'] = ("FFB9","C462","FE40")
house_sensors['id_12'] = ("FAF2","C46A","F9E2")
house_sensors['id_5'] = ("FF89","C2DF","C61E","0574","0556")
house_sensors['id_8'] = ("05C5","C450","F731")
house_sensors['id_16'] = ("FADD","F32C","C461","C46D","054D")
house_sensors['id_17'] = ("FCA1","FA8B","C60D","C445","FE5A")
house_sensors['id_13'] = ("F9B3","C411","FAE9")
house_sensors['id_19'] = ("FCD0","C2FE","C622","F5DF","FE2C")
house_sensors['id_18'] = ("FAFD","C441","FE0B")
house_sensors['id_7'] = ("C401","FCC9","C649","FE29","FFC3")
house_sensors['id_14'] = ("C43B","F5BF","FFA6")
house_sensors['id_15'] = ("C612","F995","FE01")

house_list = list(house_sensors.keys())

# %%
#Sensor Type List
sensor_type = {}
sensor_type['id_1']= ("living_temp","living_energy","ambient_temp")
sensor_type['id_10'] = ("ambient_temp","living_energy","living_temp")
sensor_type['id_9'] = ("ambient_temp","room_energy","room_temp")
sensor_type['id_20'] = ("ambient_temp","living_energy","living_temp")
sensor_type['id_3'] = ("ambient_temp","living_energy","living_temp")
sensor_type['id_4'] = ("living_temp","living_energy","ambient_temp")
sensor_type['id_11'] = ("ambient_temp","room_energy","room_temp")
sensor_type['id_12'] = ("room_temp","room_energy","ambient_temp")
sensor_type['id_5'] = ("living_temp","room_energy","living_energy","room_temp","ambient_temp")
sensor_type['id_8'] = ("living_temp","living_energy","ambient_temp")
sensor_type['id_16'] = ("ambient_temp","room_temp","living_energy","room_energy","living_temp")
sensor_type['id_17'] = ("living_temp","ambient_temp","living_energy","room_energy","room_temp")
sensor_type['id_13'] = ("room_temp","room_energy","ambient_temp")
sensor_type['id_19'] = ("living_temp","room_energy","living_energy","ambient_temp","room_temp")
sensor_type['id_18'] = ("room_temp","room_energy","ambient_temp")
sensor_type['id_7'] = ("living_energy","living_temp","room_energy","room_temp","ambient_temp")
sensor_type['id_14'] = ("room_energy","room_temp","ambient_temp")
sensor_type['id_15'] = ("living_energy","living_temp","ambient_temp")

# %%
##### Senor Data Analysis


#df_total = pd.read_sql("SELECT DISTINCT ON (index,timestamp, value, sensor_type_id) * FROM id_9 order by timestamp;",engine)


###1. Delete duplicates in postgres! CHECK TABLES!

# %%
for house_id in house_list:
     # for house_id in house_list:
    df_total = pd.read_sql("SELECT DISTINCT ON (index,timestamp, value, sensor_type_id) * FROM " + house_id + " order by timestamp;",engine)

    #Get house 
    this_house_df = df_total
    house_sensors_list = house_sensors[this_house_df['house_name'].unique()[0]]
    sensor_type_list = sensor_type[this_house_df['house_name'].unique()[0]]

    characteris = pd.DataFrame([house_sensors_list,sensor_type_list]).T
    characteris.columns = ['sensor_id','type']

    print("    ")
    print("    ")
    print("HOUSE ID " + str(this_house_df['house_name'].unique()[0]))
    print("    ")

    if len(sensor_type_list) == 3:
        if 'room_energy' in sensor_type_list:
            room_energy_str = characteris[characteris['type'] == 'room_energy']['sensor_id'].reset_index()['sensor_id'][0]
            room_temp_str = characteris[characteris['type'] == 'room_temp']['sensor_id'].reset_index()['sensor_id'][0]
            ambient_temp_str = characteris[characteris['type'] == 'ambient_temp']['sensor_id'].reset_index()['sensor_id'][0]

            room_energy_df = this_house_df[(this_house_df['sensor_id'] == room_energy_str)].drop_duplicates(subset=['timestamp','value'])
            room_temp_df = this_house_df[(this_house_df['sensor_id'] == room_temp_str)].drop_duplicates(subset=['timestamp','value'])
            ambient_temp_df = this_house_df[(this_house_df['sensor_id'] == ambient_temp_str)].drop_duplicates(subset=['timestamp','value'])

            #Implement Summary Function
            if len(room_energy_df['index']) >0:
                sensor_summary(room_energy_df)
            room_temp_df_plot = sensor_summary(room_temp_df)
            ambient_temp_df_plot = sensor_summary(ambient_temp_df)

#             plt.clf()
#             plt.plot(room_temp_df_plot['timestamp'],room_temp_df_plot['value'])
#             plt.plot(ambient_temp_df_plot['timestamp'],ambient_temp_df_plot['value'])
#             plt.show()

        else:
            living_energy_str = characteris[characteris['type'] == 'living_energy']['sensor_id'].reset_index()['sensor_id'][0]
            living_temp_str = characteris[characteris['type'] == 'living_temp']['sensor_id'].reset_index()['sensor_id'][0]
            ambient_temp_str = characteris[characteris['type'] == 'ambient_temp']['sensor_id'].reset_index()['sensor_id'][0]

            living_energy_df = this_house_df[(this_house_df['sensor_id'] == living_energy_str)].drop_duplicates(subset=['timestamp','value'])
            living_temp_df = this_house_df[(this_house_df['sensor_id'] == living_temp_str)].drop_duplicates(subset=['timestamp','value'])
            ambient_temp_df = this_house_df[(this_house_df['sensor_id'] == ambient_temp_str)].drop_duplicates(subset=['timestamp','value'])

            #Implement Summary Function
            if len(living_energy_df['index']) >0:
                sensor_summary(living_energy_df)
            living_temp_df_plot = sensor_summary(living_temp_df)
            ambient_temp_df_plot = sensor_summary(ambient_temp_df)

            plt.clf()
            plt.plot(living_temp_df_plot['timestamp'],living_temp_df_plot['value'])
            plt.plot(ambient_temp_df_plot['timestamp'],ambient_temp_df_plot['value'])
            plt.show()

    else:
        living_energy_str = characteris[characteris['type'] == 'living_energy']['sensor_id'].reset_index()['sensor_id'][0]
        living_temp_str = characteris[characteris['type'] == 'living_temp']['sensor_id'].reset_index()['sensor_id'][0]
        room_energy_str = characteris[characteris['type'] == 'room_energy']['sensor_id'].reset_index()['sensor_id'][0]
        room_temp_str = characteris[characteris['type'] == 'room_temp']['sensor_id'].reset_index()['sensor_id'][0]
        ambient_temp_str = characteris[characteris['type'] == 'ambient_temp']['sensor_id'].reset_index()['sensor_id'][0]

        room_energy_df = this_house_df[(this_house_df['sensor_id'] == room_energy_str)].drop_duplicates(subset=['timestamp','value'])
        room_temp_df = this_house_df[(this_house_df['sensor_id'] == room_temp_str)].drop_duplicates(subset=['timestamp','value'])
        living_energy_df = this_house_df[(this_house_df['sensor_id'] == living_energy_str)].drop_duplicates(subset=['timestamp','value'])
        living_temp_df = this_house_df[(this_house_df['sensor_id'] == living_temp_str)].drop_duplicates(subset=['timestamp','value'])
        ambient_temp_df = this_house_df[(this_house_df['sensor_id'] == ambient_temp_str)].drop_duplicates(subset=['timestamp','value'])


        #Implement Summary Function
        if len(living_energy_df['index']) >0:
            living_energy_df_plot = sensor_summary(living_energy_df)
            room_energy_df_plot =sensor_summary(room_energy_df)
        living_temp_df_plot = sensor_summary(living_temp_df)
        ambient_temp_df_plot = sensor_summary(ambient_temp_df)
        room_temp_df_plot = sensor_summary(room_temp_df)

        plt.clf()
        plt.plot(room_temp_df_plot['timestamp'],room_temp_df_plot['value'],color='blue')
        plt.plot(living_temp_df_plot['timestamp'],living_temp_df_plot['value'],color='red')
        plt.plot(ambient_temp_df_plot['timestamp'],ambient_temp_df_plot['value'],color='yellow')
        plt.show()
# Out:
#
#
# HOUSE ID id_1
#
# Sensor ID is FCFE
# Sensor Type is living_temp
# Sensor Type is FCFE
# Last Date: 2019-06-01
# Number of days in sample: 26
# Number of samples: 147964
# Number of NAs: 0
# count    147964.000000
# mean         29.799813
# std           1.191602
# min          25.625000
# 25%          28.937500
# 50%          29.687500
# 75%          30.625000
# max          33.750000
# Name: value, dtype: float64
# Sensor ID is F991
# Sensor Type is ambient_temp
# Sensor Type is F991
# Last Date: 2019-06-01
# Number of days in sample: 26
# Number of samples: 148007
# Number of NAs: 0
# count    148007.000000
# mean         29.854206
# std           1.222190
# min          25.250000
# 25%          28.937500
# 50%          29.750000
# 75%          30.687500
# max          34.312500
# Name: value, dtype: float64
#
#
# HOUSE ID id_10
#
# Sensor ID is FCE4
# Sensor Type is living_temp
# Sensor Type is FCE4
# Last Date: 2019-05-31
# Number of days in sample: 26
# ...

# %%
### Creating an output of CSV Files

df_energy_list = []
for house_id in house_list:
     # for house_id in house_list:
    df_total = pd.read_sql("SELECT DISTINCT ON (index,timestamp, value, sensor_type_id) * FROM " + house_id + " order by timestamp;",engine)
    df_total.to_csv("/Users/diego/Desktop/Sonora Data Dump/" + str(house_id) + ".csv")

# %%
# Out:
# '/Users/diego/Desktop/Sonora Data Dump/hd_1.csv'

# %%
##### Analyze Data
appended_data = df_total

appended_data['sensor_id'].unique()
# Out:
# array(['25A4', '07A3', 'F335'], dtype=object)

# %%
appended_data['datetime'] = pd.to_datetime(appended_data['timestamp'], format = "%Y-%M-%D %H:%M%S")

# %%
appended_data.head()
# Out:
#    index          created_at           timestamp   value sensor_type_id  \
# 0      0 2019-04-03 07:05:42 2019-04-02 23:13:17  1.0000           None
# 1      1 2019-04-10 21:05:13 2019-04-02 23:13:17  1.0000              1
# 2      2 2019-04-07 04:49:47 2019-04-02 23:13:17  1.0000              7
# 3      3 2019-04-03 07:05:42 2019-04-02 23:14:17  0.3125           None
# 4      4 2019-04-10 21:05:13 2019-04-02 23:14:17  0.3125              1
#
#    channel sensor_id house_name            datetime
# 0        0      25A4   taqueria 2019-04-02 23:13:17
# 1        0      25A4   taqueria 2019-04-02 23:13:17
# 2        0      25A4   taqueria 2019-04-02 23:13:17
# 3        0      25A4   taqueria 2019-04-02 23:14:17
# 4        0      25A4   taqueria 2019-04-02 23:14:17

# %%
# Taqueria and Datetime
ener_25A4 = appended_data[(appended_data["sensor_id"] == "25A4") & (appended_data["sensor_type_id"] == '1')]
temp_F335 = appended_data[appended_data["sensor_id"] == "F335"]
temp_07A3 = appended_data[appended_data["sensor_id"] == "07A3"]

# %%
#

# %%
##### Energy Setup
# Calculating Power
ener_25A4.loc[:,'power'] = ener_25A4['value'] * 220

#Sorby timestamp and get seconds between each time stamp
ener_25A4.sort_values(by='datetime', inplace=True)
ener_25A4.loc[:,'duration_hr'] = (ener_25A4['datetime'] - ener_25A4['datetime'].shift(1)) / np.timedelta64(1,'h')

# Energy
ener_25A4.loc[:,'energy_wh'] = ener_25A4['power'] * ener_25A4['duration_hr']
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# One Day
that_day_ener = ener_25A4[(ener_25A4['datetime'] >= datetime(2019, 4,10,20,0))]
that_day_temp1 = temp_F335[temp_F335['datetime'] >= datetime(2019, 4,10,20,0)]
that_day_temp2 = temp_07A3[temp_07A3['datetime'] >= datetime(2019, 4,10,20,0)]

# %%
plt.plot(ener_25A4['datetime'],ener_25A4['energy_wh'])
plt.show()

# %%
plt.plot(that_day_temp1['datetime'],that_day_temp1['value'])
plt.show()

# %%
plt.plot(that_day_temp2['datetime'],that_day_temp2['value'])
plt.show()

# %%
if this_value == 'None':
    this_value = 'NaN'
else:

# %% [markdown]
# SONORA V2 Implementation

# %% [markdown]
# 1. Prepare mission name PER SENSOR: "house_id7_FF09"

# %% [markdown]
# 1. Prepare a data export from geocene.com
# 2. Call the name of the folder that downloads with a date "geocene_data_download_XXX"
# 3. Move the file to "input_data"
#
# NOTE:
#
# 1. The mission is created once the data is uploaded. Write down the name of the mission so that the script is ready,

# %%
path = "/Users/diego/Desktop/Projects_Code/sonora_cooling_code/inputs/geocene_data_download_nov2_2022/metrics/"
output_path = "/Users/diego/Desktop/Projects_Code/sonora_cooling_code/data_dumps/october/"

# %%
# Missions
# ALWAYS
# missions['house_id'] = ("ac_temp_sensor","ambient_sensor","energy_sensor")
# missions['house_id'] = ("ac_temp_sensor","ac_temp_sensor","ambient_sensor","energy_sensor","energy_sensor")
# Make sure you create the dictionary 

missions={}
# Three Sensors
missions['id_1']=("house_id1_f33e-628fba0c-0000-0000-0000-cc78ab77f33e.csv","house_id1_f9b8-628fba31-0000-0000-0000-cc78ab77f9b8.csv","house_id1_c417-628fb9e8-0000-0000-0000-a0e6f850c417.csv")
#OLD missions['id_3']=("house_id3_05c5-628fc44b-0000-0000-0000-cc78ab6e05c5.csv","house_id3_f731-628fc495-0000-0000-0000-cc78ab77f731.csv","house_id_c605-628fc4c7-0000-0000-0000-a0e6f850c605.csv")
missions['id_3']=("house_id3_05c5-628fc44b-0000-0000-0000-cc78ab6e05c5.csv","house_id3_f731-628fc495-0000-0000-0000-cc78ab77f731.csv","house_id_3_c622-62c38674-0000-0000-0000-a0e6f850c622.csv")
missions['id_4']=("house_id4_f995-628fcf54-0000-0000-0000-cc78ab77f995.csv","house_id4_fe0b-628fcfa8-0000-0000-0000-cc78ab77fe0b.csv","house_id4_c641-628fcf73-0000-0000-0000-a0e6f850c641.csv")
missions['id_7']=("house_id7_fe40-6290105f-0000-0000-0000-cc78ab77fe40.csv","house_id7_f99e-62901091-0000-0000-0000-cc78ab77f99e.csv","house_id7_c2fe-62900345-0000-0000-0000-a0e6f850c2fe.csv")
# OLD missions['id_9']=("house_id9_f32c-628fdaaf-0000-0000-0000-cc78ab77f32c.csv","house_id9_fae9-628fdadd-0000-0000-0000-cc78ab77fae9.csv","house_id9_c41e-628fe267-0000-0000-0000-a0e6f850c41e.csv")
missions['id_9']=("house_id9_f32c-628fdaaf-0000-0000-0000-cc78ab77f32c.csv","house_id9_fae9-628fdadd-0000-0000-0000-cc78ab77fae9.csv","house_id_9_c462-6313a1e2-0000-0000-0000-a0e6f850c462.csv")
# OLD TEMPERATURE SENSORS missions['id_13']=("house_id13_f9e2-628fd37a-0000-0000-0000-cc78ab77f9e2.csv","house_id13_faf2-628fd3b9-0000-0000-0000-cc78ab77faf2.csv","house_id13_c42f-628fd340-0000-0000-0000-a0e6f850c42f.csv")
# OLD August 3rd missions['id_13']=("house_id_13_f5df-62c38016-0000-0000-0000-cc78ab77f5df.csv","house_id_13-ffb9-62c37f4b-0000-0000-0000-cc78ab77ffb9.csv","house_id13_c42f-628fd340-0000-0000-0000-a0e6f850c42f.csv")
missions['id_13']=("house_id_13-fcd0-2022-08-03-1217-62eaca24-0000-0000-0000-cc78ab77fcd0.csv","house_id_13-ffb9-62c37f4b-0000-0000-0000-cc78ab77ffb9.csv","house_id13_c42f-628fd340-0000-0000-0000-a0e6f850c42f.csv")
missions['id_14']=("house_id14_f991-628fae7f-0000-0000-0000-cc78ab77f991.csv","house_id14_fcfe-628faed3-0000-0000-0000-cc78ab77fcfe.csv","house_id14_c602-628fac1c-0000-0000-0000-a0e6f850c602.csv")
# OLD August missions['id_15']=("house_id15_fe44-62900e73-0000-0000-0000-cc78ab77fe44.csv","house_id15_fe01-62900ec9-0000-0000-0000-cc78ab77fe01.csv","house_id15_c612-62900e43-0000-0000-0000-a0e6f850c612.csv")
# OLDmissions['id_15']=("house_id_15-_d574-2022-08-03-1344-62eade6c-0000-0000-0000-cc78ab6e0574.csv","house_id15_fe01-62900ec9-0000-0000-0000-cc78ab77fe01.csv","house_id15_c612-62900e43-0000-0000-0000-a0e6f850c612.csv")
missions['id_15']=("house_id_15_fce4-6313a53a-0000-0000-0000-cc78ab77fce4.csv","house_id15_fe01-62900ec9-0000-0000-0000-cc78ab77fe01.csv","house_id15_c612-62900e43-0000-0000-0000-a0e6f850c612.csv")
# OLD August 3rd missions['id_16']=("house_id16_054d-628ff218-0000-0000-0000-cc78ab6e054d.csv","house_id16_fafd-628ff252-0000-0000-0000-cc78ab77fafd.csv","house_id16_c411-628ff1e5-0000-0000-0000-a0e6f850c411.csv")
missions['id_16']=("house_id16_054d-628ff218-0000-0000-0000-cc78ab6e054d.csv","house_id16_fafd-628ff252-0000-0000-0000-cc78ab77fafd.csv","house-_id_16-c2df-2022-08-03-1303-62ead4d2-0000-0000-0000-a0e6f850c2df.csv")
missions['id_20']=("house_id20_0581-628fc00a-0000-0000-0000-cc78ab6e0581.csv","house_id20_0581-628fc00a-0000-0000-0000-cc78ab6e0581.csv","house_id20_c40b-628fbf7c-0000-0000-0000-a0e6f850c40b.csv")
# Five Sensors
missions['id_5']=("house_id5_fe29-628fe64e-0000-0000-0000-cc78ab77fe29.csv","house_id5_ffc9-628fe5e3-0000-0000-0000-cc78ab77fcc9.csv","house_id5_ffc3-628fe5bd-0000-0000-0000-cc78ab77ffc3.csv","house_id_5_c630-6312b08f-0000-0000-0000-a0e6f850c630.csv","house_id5_c2fb-628fe60d-0000-0000-0000-a0e6f850c2fb.csv")
missions['id_17']=("house_id17_ffa6-628ffb38-0000-0000-0000-cc78ab77ffa6.csv","house_id17_f9e0-628ffb77-0000-0000-0000-cc78ab77f9e0.csv","house_id17_f5bf-628ffbb1-0000-0000-0000-cc78ab77f5bf.csv","house_id17_c43b-628ffaa9-0000-0000-0000-a0e6f850c43b.csv","house_id17_c44a-628ffb00-0000-0000-0000-a0e6f850c44a.csv")
missions['id_19']=("house_id19_fa8b-628fb636-0000-0000-0000-cc78ab77fa8b.csv","house_id19_fa8b-628fb636-0000-0000-0000-cc78ab77fa8b.csv","house_id19_fe5a-628fb752-0000-0000-0000-cc78ab77fe5a.csv","house_id19_c445-628fb2e3-0000-0000-0000-a0e6f850c445.csv","house_id19_c465-628fb348-0000-0000-0000-a0e6f850c465.csv")

#missions['id_7']=("dot-f995-2022-05-21-221232-6289aa20-0000-0000-0000-cc78ab77f995.csv","dot-f995-2022-05-21-221232-6289aa20-0000-0000-0000-cc78ab77f995.csv","dot-f995-2022-05-21-221232-6289aa20-0000-0000-0000-cc78ab77f995.csv")
#missions['id_19']=("dot-f995-2022-05-21-221232-6289aa20-0000-0000-0000-cc78ab77f995.csv","dot-f995-2022-05-21-221232-6289aa20-0000-0000-0000-cc78ab77f995.csv","dot-f995-2022-05-21-221232-6289aa20-0000-0000-0000-cc78ab77f995.csv","dot-f995-2022-05-21-221232-6289aa20-0000-0000-0000-cc78ab77f995.csv","dot-f995-2022-05-21-221232-6289aa20-0000-0000-0000-cc78ab77f995.csv")

# %%
date_limit = pd.to_datetime('2022-05-23',utc=True)

# %%
# name_sensor = data_sensor['mission_id'][0][-4:]
# name_sensor

# %%
for mission in missions:
    print("Household ID: "+ str(mission))
    
    mission_list_dfs=[]
    if len(missions[mission])==3:
        print("3 SENSORS TOTAL")
        
        for num in range(0,3):
        
            data_sensor = pd.read_csv(path+missions[mission][num])
            data_sensor['timestamp'] = pd.to_datetime(data_sensor['timestamp'])
            name_sensor = data_sensor['mission_id'][0][-4:]
            length_days = len(data_sensor['timestamp'].dt.date.unique())
            
            first_date = data_sensor['timestamp'].sort_values(ascending=True).reset_index()['timestamp'][0].date()
            recent_date = data_sensor['timestamp'].sort_values(ascending=False).reset_index()['timestamp'][0].date()

            
            nom = len(data_sensor['timestamp'])
            denom = ((recent_date-first_date).days*24*60)

            if denom > 0:
                pct_sample_data_completion = nom/denom
            else:
                pct_sample_data_completion = 0

    #         data_2 = pd.read_csv(path+missions[mission][1])
    #         data_2['timestamp'] = pd.to_datetime(data_2['timestamp'])
    #         name_sensor_2 = data_2['mission_id'][0][-4:]
    #         length_days_2 = len(data_2['timestamp'].dt.date.unique())

    #         data_3 = pd.read_csv(path+missions[mission][2])
    #         data_3['timestamp'] = pd.to_datetime(data_3['timestamp'])
    #         name_sensor_3 = data_3['mission_id'][0][-4:]
    #         length_days_3 = len(data_2['timestamp'].dt.date.unique())

            print(("Sensor name is " + str(name_sensor)))
            print("Number of days in sample: " + str(length_days))
            print("Data % Completion: " + str(pct_sample_data_completion))
            print("Most recent date: " + str(recent_date))
            print("")
            print(data_sensor['value'].describe())
            print("-")
            print("-")
            
            mission_list_dfs.append(data_sensor)
            
        # Print Graphs
        
        #Plot data for the last 10 days to ensure that everything is OK
        last_date = (datetime.now() - timedelta(days=10)).date()
        
        plot_df1 = mission_list_dfs[0][mission_list_dfs[0]['timestamp'].dt.date>last_date]
        plot_df2 = mission_list_dfs[1][mission_list_dfs[1]['timestamp'].dt.date>last_date]
        plot_df3 = mission_list_dfs[2][mission_list_dfs[2]['timestamp'].dt.date>last_date]
        
        plt.clf()
        plt.plot(plot_df1['timestamp'],plot_df1['value'],color='red')
        plt.plot(plot_df2['timestamp'],plot_df2['value'],color='blue')
        plt.show()
        
        plt.clf()
        plt.plot(plot_df3['timestamp'],(plot_df3['value']*220)/60,color='green')
        plt.show()
        
        # Assigning values and creating output
        mission_list_dfs[0]['sensor_type'] = 'ac_temp_sensor'
        mission_list_dfs[0]['sensor_name'] = mission_list_dfs[0]['mission_id'][0][-4:]
        mission_list_dfs[0]['house_name'] = mission
        mission_list_dfs[0]['energy_wh'] = "NA"
        
        mission_list_dfs[1]['sensor_type'] = 'ambient_temp_sensor'
        mission_list_dfs[1]['sensor_name'] = mission_list_dfs[1]['mission_id'][1][-4:]
        mission_list_dfs[1]['house_name'] = mission
        mission_list_dfs[1]['energy_wh'] = "NA"
        
        mission_list_dfs[2]['sensor_type'] = 'ac_energy_sensor'
        mission_list_dfs[2]['sensor_name'] = mission_list_dfs[2]['mission_id'][2][-4:]
        mission_list_dfs[2]['house_name'] = mission
        mission_list_dfs[2]['energy_wh'] = (mission_list_dfs[2]['value']*220)/60
        
        appended_df = pd.concat([mission_list_dfs[0],mission_list_dfs[1],mission_list_dfs[2]])[['house_name','timestamp','sensor_type','sensor_name','value','energy_wh']]
        appended_df_sub = appended_df[appended_df['timestamp']>=date_limit]
        
        appended_df_sub.to_csv(output_path+str(mission)+"_"+str(datetime.now().date())+".csv")
        
    elif len(missions[mission])==5:
        print("5 SENSORS TOTAL")
        
        for num in range(0,5):
        
            data_sensor = pd.read_csv(path+missions[mission][num])
            data_sensor['timestamp'] = pd.to_datetime(data_sensor['timestamp'])
            name_sensor = data_sensor['mission_id'][0][-4:]
            length_days = len(data_sensor['timestamp'].dt.date.unique())
            
            first_date = data_sensor['timestamp'].sort_values(ascending=True).reset_index()['timestamp'][0].date()
            recent_date = data_sensor['timestamp'].sort_values(ascending=False).reset_index()['timestamp'][0].date()

            pct_sample_data_completion = len(data_sensor['timestamp'])/((recent_date-first_date).days*24*60)

    #         data_2 = pd.read_csv(path+missions[mission][1])
    #         data_2['timestamp'] = pd.to_datetime(data_2['timestamp'])
    #         name_sensor_2 = data_2['mission_id'][0][-4:]
    #         length_days_2 = len(data_2['timestamp'].dt.date.unique())

    #         data_3 = pd.read_csv(path+missions[mission][2])
    #         data_3['timestamp'] = pd.to_datetime(data_3['timestamp'])
    #         name_sensor_3 = data_3['mission_id'][0][-4:]
    #         length_days_3 = len(data_2['timestamp'].dt.date.unique())

            print(("Sensor name is " + str(name_sensor)))
            print("Number of days in sample: " + str(length_days))
            print("Data % Completion: " + str(pct_sample_data_completion))
            print("Most recent date: " + str(recent_date))
            print("")
            print(data_sensor['value'].describe())
            print("-")
            print("-")
            
            mission_list_dfs.append(data_sensor)
            
        # Print Graphs
        
        #Plot data for the last 10 days to ensure that everything is OK
        last_date = (datetime.now() - timedelta(days=10)).date()
        
        plot_df1 = mission_list_dfs[0][mission_list_dfs[0]['timestamp'].dt.date>last_date]
        plot_df2 = mission_list_dfs[1][mission_list_dfs[1]['timestamp'].dt.date>last_date]
        plot_df3 = mission_list_dfs[2][mission_list_dfs[2]['timestamp'].dt.date>last_date]
        plot_df4 = mission_list_dfs[3][mission_list_dfs[3]['timestamp'].dt.date>last_date]
        plot_df5 = mission_list_dfs[4][mission_list_dfs[4]['timestamp'].dt.date>last_date]
        
        plt.clf()
        plt.plot(plot_df1['timestamp'],plot_df1['value'],color='red')
        plt.plot(plot_df2['timestamp'],plot_df2['value'],color='blue')
        plt.plot(plot_df3['timestamp'],plot_df3['value'],color='orange')
        plt.show()
            
        
        plt.clf()
        plt.plot(plot_df4['timestamp'],(plot_df4['value']*220)/60,color='green')
        plt.plot(plot_df5['timestamp'],(plot_df5['value']*220)/60,color='black')
        plt.show()
        
        # Assigning values and creating output
        mission_list_dfs[0]['sensor_type'] = 'ac_temp_sensor'
        mission_list_dfs[0]['sensor_name'] = mission_list_dfs[0]['mission_id'][0][-4:]
        mission_list_dfs[0]['house_name'] = mission
        mission_list_dfs[0]['energy_wh'] = "NA"
        
        mission_list_dfs[1]['sensor_type'] = 'ambient_temp_sensor'
        mission_list_dfs[1]['sensor_name'] = mission_list_dfs[1]['mission_id'][1][-4:]
        mission_list_dfs[1]['house_name'] = mission
        mission_list_dfs[1]['energy_wh'] = "NA"
        
        mission_list_dfs[2]['sensor_type'] = 'ambient_temp_sensor'
        mission_list_dfs[2]['sensor_name'] = mission_list_dfs[2]['mission_id'][2][-4:]
        mission_list_dfs[2]['house_name'] = mission
        mission_list_dfs[2]['energy_wh'] = "NA"
        
        mission_list_dfs[3]['sensor_type'] = 'ac_energy_sensor'
        mission_list_dfs[3]['sensor_name'] = mission_list_dfs[3]['mission_id'][3][-4:]
        mission_list_dfs[3]['house_name'] = mission
        mission_list_dfs[3]['energy_wh'] = (mission_list_dfs[3]['value']*220)/60
        
        mission_list_dfs[4]['sensor_type'] = 'ac_energy_sensor'
        mission_list_dfs[4]['sensor_name'] = mission_list_dfs[4]['mission_id'][4][-4:]
        mission_list_dfs[4]['house_name'] = mission
        mission_list_dfs[4]['energy_wh'] = (mission_list_dfs[4]['value']*220)/60
        
        appended_df = pd.concat([mission_list_dfs[0],mission_list_dfs[1],mission_list_dfs[2],mission_list_dfs[3],mission_list_dfs[4]])[['house_name','timestamp','sensor_type','sensor_name','value','energy_wh']]
        appended_df_sub = appended_df[appended_df['timestamp']>=date_limit]
        
        appended_df_sub.to_csv(output_path+str(mission)+"_"+str(datetime.now().date())+".csv")
# Out:
# Household ID: id_1
# 3 SENSORS TOTAL
# Sensor name is F33E
# Number of days in sample: 156
# Data % Completion: 1.000448028673835
# Most recent date: 2022-10-28
#
# count    223300.000000
# mean         30.775045
# std           4.912226
# min           7.187500
# 25%          29.625000
# 50%          31.750000
# 75%          33.500000
# max          41.625000
# Name: value, dtype: float64
# -
# -
# Sensor name is F9B8
# Number of days in sample: 156
# Data % Completion: 1.0004569892473119
# Most recent date: 2022-10-28
#
# count    223302.000000
# mean         32.204316
# std           2.557656
# min          24.562500
# 25%          30.250000
# 50%          32.375000
# 75%          33.937500
# max          41.687500
# Name: value, dtype: float64
# -
# -
# Sensor name is C417
# Number of days in sample: 156
# Data % Completion: 0.9953763440860215
# Most recent date: 2022-10-28
#
# count    222168.000000
# mean          0.493260
# std           2.067011
# min           0.000000
# ...

# %% [markdown]
# Merida Sensor Analysis
